# %%
# !pip install torch transformers langchain huggingface-hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 986.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.0/408.0 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login

login("YOUR_HUGGINGFACE_TOKEN")  # Replace with your Hugging Face token
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-478f04344e78> in <cell line: 3>()
#       1 from huggingface_hub import login
#       2
# ----> 3 login("YOUR_HUGGINGFACE_TOKEN")  # Replace with your Hugging Face token
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_login.py in login(token, add_to_git_credential, new_session, write_permission)
#     109                 "you want to set the git credential as well."
#     110             )
# --> 111         _login(token, add_to_git_credential=add_to_git_credential, write_permission=write_permission)
#     112     elif is_notebook():
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
# Load the tokenizer and model for GPT-NeoX 20B
model_name = "EleutherAI/from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Set up a pipeline for text generation
llm_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=256,
    temperature=0.7,
    device=0  # Use GPU (0) or CPU (-1)
)

# Initialize LangChain's LLM with the Hugging Face pipeline
llm = HuggingFacePipeline(pipeline=llm_pipeline)
"  # The model ID for GPT-NeoX 20B

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", torch_dtype=torch.float16)  # Using mixed precision
# Out:
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# ...
# model-00001-of-00046.safetensors:   0%|          | 0.00/926M [00:00<?, ?B/s]
# model-00002-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00003-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00004-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00005-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00006-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00007-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00008-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00009-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# model-00010-of-00046.safetensors:   0%|          | 0.00/910M [00:00<?, ?B/s]
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import HuggingFacePipeline
from transformers import pipeline

# Set up a pipeline for text generation
llm_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=25,
    temperature=0.7,
)

# Initialize LangChain's LLM with the Hugging Face pipeline
llm = HuggingFacePipeline(pipeline=llm_pipeline)

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Create a prompt template
prompt = PromptTemplate.from_template("Who won world cup {data}")

# Set up the LangChain LLM Chain
chain = LLMChain(llm=llm, prompt=prompt)

# Test the chain with sample data
data = "2014"
response = chain.run(data=data)
print(response)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Create a prompt template
prompt = PromptTemplate.from_template("Who won the World Cup in {data}?")

# Set up the LangChain LLM Chain
chain = LLMChain(llm=llm, prompt=prompt)

# Test the chain with sample data
data = "2014"
try:
    response = chain.run(data=data)
    print(response)
except Exception as e:
    print("An error occurred:", str(e))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:567: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-03a8be2f7b0d> in <cell line: 12>()
#      11 data = "2014"
#      12 try:
# ---> 13     response = chain.run(data=data)
#      14     print(response)
#      15 except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
# ...
