# %%
# Import Libraries
import ollama
from langchain.document_loaders import DirectoryLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
import pinecone
from langchain_community.llms import Ollama
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# Function to Load Documents
def read_doc(directory):
    # Read all files in the specified directory
    file_loader = DirectoryLoader(directory)
    documents = file_loader.load()
    return documents

# %%
# Load Documents from Directory
doc = read_doc("documents/")

doc
# Out:
# Error loading file documents\budget_speech.pdf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Load Documents from Directory
# ----> 2 doc = read_doc("documents/")
#       4 doc
#
# Cell In[10], line 5, in read_doc(directory)
#       2 def read_doc(directory):
#       3     # Read all files in the specified directory
#       4     file_loader = DirectoryLoader(directory)
# ----> 5     documents = file_loader.load()
#       6     return documents
#
# File d:\Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File d:\Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# File d:\Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\directory.py:233, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     231     else:
#     232         logger.error(f"Error loading file {str(item)}")
# --> 233         raise e
#     234 finally:
#     235     if pbar:
#
# File d:\Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\directory.py:223, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     221 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     222 try:
# --> 223     for subdoc in loader.lazy_load():
#     224         yield subdoc
#     225 except NotImplementedError:
#
# File d:\Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File d:\Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\unstructured.py:228, in UnstructuredFileLoader._get_elements(self)
#     226 if isinstance(self.file_path, Path):
#     227     self.file_path = str(self.file_path)
# --> 228 return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\partition\auto.py:181, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, detect_language_per_element, pdf_infer_table_structure, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, xml_keep_tags, data_source_metadata, metadata_filename, request_timeout, hi_res_model_name, model_name, starting_page_number, **kwargs)
#     176     if headers != {}:
#     177         logger.warning(
#     178             "The headers kwarg is set but the url kwarg is not. "
#     179             "The headers kwarg will be ignored.",
#     180         )
# --> 181     file_type = detect_filetype(
#     182         file_path=filename,
#     183         file=file,
#     184         encoding=encoding,
#     185         content_type=content_type,
#     186         metadata_file_path=metadata_filename,
#     187     )
#     189 if file is not None:
#     190     file.seek(0)
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\file_utils\filetype.py:98, in detect_filetype(file_path, file, encoding, content_type, metadata_file_path)
#      64 """Determine file-type of specified file using libmagic and/or fallback methods.
#      65
#      66 One of `file_path` or `file` must be specified. A `file_path` that does not
#    (...)
#      89     - Neither `file_path` nor `file` were specified.
#      90 """
#      91 ctx = _FileTypeDetectionContext.new(
#      92     file_path=file_path,
#      93     file=file,
#    (...)
#      96     metadata_file_path=metadata_file_path,
#      97 )
# ---> 98 return _FileTypeDetector.file_type(ctx)
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\file_utils\filetype.py:131, in _FileTypeDetector.file_type(cls, ctx)
#     128 @classmethod
#     129 def file_type(cls, ctx: _FileTypeDetectionContext) -> FileType:
#     130     """Detect file-type of document-source described by `ctx`."""
# --> 131     return cls(ctx)._file_type
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\file_utils\filetype.py:141, in _FileTypeDetector._file_type(self)
#     138     return file_type
#     140 # -- strategy 2: guess MIME-type using libmagic and use that --
# --> 141 if file_type := self._file_type_from_guessed_mime_type:
#     142     return file_type
#     144 # -- strategy 3: use filename-extension, like ".docx" -> FileType.DOCX --
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\file_utils\filetype.py:181, in _FileTypeDetector._file_type_from_guessed_mime_type(self)
#     174 @property
#     175 def _file_type_from_guessed_mime_type(self) -> FileType | None:
#     176     """FileType based on auto-detection of MIME-type by libmagic.
#     177
#     178     In some cases refinements are necessary on the magic-derived MIME-types. This process
#     179     includes applying those rules, most of which are accumulated through practical experience.
#     180     """
# --> 181     mime_type = self._ctx.mime_type
#     182     extension = self._ctx.extension
#     184     # -- when libmagic is not installed, the `filetype` package is used instead.
#     185     # -- `filetype.guess()` returns `None` for file-types it does not support, which
#     186     # -- unfortunately includes all the textual file-types like CSV, EML, HTML, MD, RST, RTF,
#     187     # -- TSV, and TXT. When we have no guessed MIME-type, this strategy is not applicable.
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\utils.py:154, in lazyproperty.__get__(self, obj, type)
#     149 value = obj.__dict__.get(self._name)
#     150 if value is None:
#     151     # --- on first access, the __dict__ item will be absent. Evaluate fget()
#     152     # --- and store that value in the (otherwise unused) host-object
#     153     # --- __dict__ value of same name ('fget' nominally)
# --> 154     value = self._fget(obj)
#     155     obj.__dict__[self._name] = value
#     156 return cast(_T, value)
#
# File d:\Langchain\myenv\Lib\site-packages\unstructured\file_utils\filetype.py:362, in _FileTypeDetectionContext.mime_type(self)
#     359 file_path = self.file_path
#     361 if LIBMAGIC_AVAILABLE:
# --> 362     import magic
#     364     mime_type = (
#     365         magic.from_file(file_path, mime=True)
#     366         if file_path
#     367         else magic.from_buffer(self.file_head, mime=True)
#     368     )
#     369     return mime_type.lower() if mime_type else None
#
# File d:\Langchain\myenv\Lib\site-packages\magic\__init__.py:209
#     206     return m.from_descriptor(fd)
#     208 from . import loader
# --> 209 libmagic = loader.load_lib()
#     211 magic_t = ctypes.c_void_p
#     214 def errorcheck_null(result, func, args):
#
# File d:\Langchain\myenv\Lib\site-packages\magic\loader.py:49, in load_lib()
#      46     pass
#      47 else:
#      48   # It is better to raise an ImportError since we are importing magic module
# ---> 49   raise ImportError('failed to find libmagic.  Check your installation')
#
# ImportError: failed to find libmagic.  Check your installation
